# %%
APIdata=read.csv(file="~/Desktop/Machine Learning Module 1/NEWSAPI.csv", sep=",", header=TRUE)
#head(APIdata) # Original Dataset Variables List 
head(APIdata)
names(APIdata)
APIdata2=subset(APIdata, select = -c(X,author,source,url,urlToImage,publishedAt,content))
head(APIdata2) # Updated dataset with only useful informations or words associated with "red wine"
# Out:
#   X source                                 author
# 1 0 {'id': None, 'name': 'Lifehacker.com'} Claire Lower
# 2 1 {'id': 'cnn', 'name': 'CNN'}           Silvia Marchetti, CNN
# 3 2 {'id': 'cnn', 'name': 'CNN'}           Opinion by Jill Filipovic
# 4 3 {'id': 'cnn', 'name': 'CNN'}           By Forrest Brown, CNN
# 5 4 {'id': 'reuters', 'name': 'Reuters'}
# 6 5 {'id': None, 'name': 'The Guardian'}   Fiona Beckett
#   title
# 1 Your BLT Needs This Stealth Bacon
# 2 8 Italian villages you may have never heard of
# 3 Opinion: New Yorkers sent an election message. And it wasn't about inflation
# 4 Best places to go for fall: A dozen cool spots around the world
# 5 Pioneering Japanese woman photojournalist dies, aged 107 - Reuters
# 6 Five underrated French wines – and the overrated to avoid | Fiona Beckett on drinks
#   description
# ...

# %%
APIdata2$title=tolower(APIdata2$title)

APIdata2$description=tolower(APIdata2$description)

head(APIdata2)
# Out:
#   title
# 1 your blt needs this stealth bacon
# 2 8 italian villages you may have never heard of
# 3 opinion: new yorkers sent an election message. and it wasn't about inflation
# 4 best places to go for fall: a dozen cool spots around the world
# 5 pioneering japanese woman photojournalist dies, aged 107 - reuters
# 6 five underrated french wines – and the overrated to avoid | fiona beckett on drinks
#   description
# 1 a blt is a pretty perfect sandwich. i don’t thing i need to explain why the combination of crispy, salty bacon, crunchy lettuce, creamy mayo, and juicy tomatoes taste good together. each component has a part to play, and they play it oh-so-well, but i think t…
# 2 travelers tend to head to the big name destinations like venice, florence, rome and even naples when visiting italy. but there are many equally, if not more, beautiful villages in the european country that are largely unknown, even among some italians.
# ...

# %%
head(APIdata)
# Out:
#   X source                                 author
# 1 0 {'id': None, 'name': 'Lifehacker.com'} Claire Lower
# 2 1 {'id': 'cnn', 'name': 'CNN'}           Silvia Marchetti, CNN
# 3 2 {'id': 'cnn', 'name': 'CNN'}           Opinion by Jill Filipovic
# 4 3 {'id': 'cnn', 'name': 'CNN'}           By Forrest Brown, CNN
# 5 4 {'id': 'reuters', 'name': 'Reuters'}
# 6 5 {'id': None, 'name': 'The Guardian'}   Fiona Beckett
#   title
# 1 Your BLT Needs This Stealth Bacon
# 2 8 Italian villages you may have never heard of
# 3 Opinion: New Yorkers sent an election message. And it wasn't about inflation
# 4 Best places to go for fall: A dozen cool spots around the world
# 5 Pioneering Japanese woman photojournalist dies, aged 107 - Reuters
# 6 Five underrated French wines – and the overrated to avoid | Fiona Beckett on drinks
#   description
# ...
